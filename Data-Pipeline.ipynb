# %% [markdown]
# <a href="https://www.kaggle.com/code/lukboss/data-dashboard-bellabeat?scriptVersionId=177636627" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <center><span style="font-size:50px; color:#000000; font-family:calibri"><b>Bellabeat Membership Program Analysis</b><span/><center/>
# <center><span style="font-size:30px; color:#4c8bf5; font-family:calibri"><b>Google Looker Dashboard<span/><center/>

# %% [markdown]
# ***Visualizations may take a while to load due to large volumes of data***

# %% [markdown]
# ### Still Image Exports
# ![GoogleLooker-EngagementCategorie.png](attachment:312c977a-ec52-461e-b684-827df9851f3a.png)
# <br>
# ![GoogleLooker-TimeSeries (1).png](attachment:91fb18c3-2c5d-440d-868f-58d1fd92ce7c.png)
